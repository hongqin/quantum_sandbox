# %% [markdown]
# <a href="https://colab.research.google.com/github/hongqin/quantum_sandbox/blob/main/FFT_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of samples
num_samples = 2**3  # Same as the number of qubits in the quantum example

# Sample the sin function at discrete intervals
x_values = np.linspace(0, 2*np.pi, num_samples, endpoint=False)
samples = np.sin(x_values)

# Plot the sampled sine function
plt.plot(x_values, samples, 'o-')
plt.title('Sampled Sine Function')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True)
plt.show()

# Perform the Discrete Fourier Transform (DFT)
dft_result = np.fft.fft(samples)

# Get the magnitudes of the frequencies
frequencies = np.fft.fftfreq(num_samples)
magnitude = np.abs(dft_result)

# Plot the magnitudes in the frequency domain
plt.stem(frequencies, magnitude)
plt.title('DFT of the Sampled Sine Function')
plt.xlabel('Frequency (cycles/sample interval)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# Find the index of the peak in the DFT magnitude
# This corresponds to the dominant frequency component
peak_index = np.argmax(magnitude)

# Estimate the frequency from the peak index
# The frequency unit is cycles/sample_interval
frequency = frequencies[peak_index]

# Estimate the period of the sine wave
# The period unit is sample_intervals/cycle
period = 1 / frequency if frequency != 0 else np.inf

# Convert the period to the corresponding x value range (2*pi in this case)
# This assumes that the sampling was done over one full period of the sine wave
period_in_x = period * (2 * np.pi)

print(f"Estimated frequency: {frequency} cycles/sample interval")
print(f"Estimated period: {period} sample intervals/cycle")
print(f"Estimated period in terms of x: {period_in_x} radians")
# Out:
# Estimated frequency: 0.125 cycles/sample interval
# Estimated period: 8.0 sample intervals/cycle
# Estimated period in terms of x: 50.26548245743669 radians
